# %% [markdown]
# <a href="https://colab.research.google.com/github/JamesAn13/JamesAn13/blob/main/%EB%AA%A8%EB%8D%B8%ED%95%99%EC%8A%B51038.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import random
import torch
import numpy as np
import gc
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torch.optim import Adam
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/trainset/
# Out:
# /content/drive/MyDrive/trainset

# %%
raw_data = []
with open('raw_data.pickle', 'rb') as f:
    raw_data = pickle.load(f)

# %%
len(raw_data)
# Out:
# 1504

# %%
random.shuffle(raw_data)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class MyDataset(Dataset):
    def __init__(self, seq_list):
        self.X = []
        self.y = []
        for dic in seq_list :
            self.y.append(dic['key'])
            self.X.append(dic['value'])

    def __getitem__(self, index):
        data = self.X[index]
        label = self.y[index]
        return torch.Tensor(np.array(data)), torch.tensor(np.array(int(label)))

    def __len__(self):
        return len(self.X)

# %%
split_ratio = [0.8, 0.1, 0.1]
train_len = int(len(raw_data) * split_ratio[0])
val_len = int(len(raw_data) * split_ratio[1])
test_len = len(raw_data) - train_len - val_len

print('{}, {}, {}'.format(train_len, val_len, test_len))
# Out:
# 1203, 150, 151

# %%
BATCH_SIZE = 20
EPOCH = 700
NUM_LAYERS = 1      # LSTM model: num_layers

# %%
train_dataset = MyDataset(raw_data)
train_data, valid_data, test_data = random_split(train_dataset, [train_len, val_len, test_len])

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE)
val_loader = DataLoader(valid_data, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
# LSTM
class skeleton_LSTM(nn.Module):
    def __init__(self):
        super(skeleton_LSTM, self).__init__()
        self.lstm1 = nn.LSTM(input_size=len(attention_dot) * 2, hidden_size=128, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=256, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm3 = nn.LSTM(input_size=256, hidden_size=512, num_layers=NUM_LAYERS, batch_first=True)
        self.dropout1 = nn.Dropout(0.1)
        self.lstm4 = nn.LSTM(input_size=512, hidden_size=256, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm5 = nn.LSTM(input_size=256, hidden_size=128, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm6 = nn.LSTM(input_size=128, hidden_size=64, num_layers=NUM_LAYERS, batch_first=True)
        self.dropout2 = nn.Dropout(0.1)
        self.lstm7 = nn.LSTM(input_size=64, hidden_size=32, num_layers=NUM_LAYERS, batch_first=True)
        self.fc = nn.Linear(32,2)

    def forward(self, x) :
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)
        x = self.dropout1(x)
        x, _ = self.lstm4(x)
        x, _ = self.lstm5(x)
        x, _ = self.lstm6(x)
        x = self.dropout2(x)
        x, _ = self.lstm7(x)
        x = self.fc(x[:,-1,:]) # x[배치 크기, 시퀀스 길이, 은닉 상태 크기], [:, -1, :] -> 마지막 시간 단계만 선택

        return x

# %%
# 모델 초기화

def init_model():
    global net, loss_fn, optim
    plt.rc('font', size = 10)
    net = skeleton_LSTM().to(device)
    loss_fn = nn.CrossEntropyLoss()
    optim = Adam(net.parameters(), lr=0.0001)

# epoch 카운터 초기화
def init_epoch():
    global epoch_cnt
    epoch_cnt = 0

# 모든 Log를 초기화
def init_log():
    global log_stack, iter_log, tloss_log, tacc_log, vloss_log, vacc_log, time_log
    plt.rc('font', size = 10)
    iter_log, tloss_log, tacc_log, vloss_log, vacc_log = [], [], [], [], []
    time_log, log_stack = [], []

# %%
def record_train_log(_tloss, _tacc, _time):
    # Train Log 기록
    time_log.append(_time)
    tloss_log.append(_tloss)
    tacc_log.append(_tacc)
    iter_log.append(epoch_cnt)

def record_valid_log(_vloss, _vacc):
    # Validation Log 기록
    vloss_log.append(_vloss)
    vacc_log.append(_vacc)

def last(log_list):
    # last 안의 마지막 숫자를 반환(print_log 함수에서 사용)
    if len(log_list) > 0:
        return log_list[len(log_list) - 1]
    else:
        return -1

def print_log():
    # 학습 추이 출력 : 소숫점 3자리까지
    train_loss = round(float(last(tloss_log)), 3)
    train_acc = round(float(last(tacc_log)), 3)
    val_loss = round(float(last(vloss_log)), 3)
    val_acc = round(float(last(vacc_log)), 3)
    time_spent = round(float(last(time_log)), 3)

    log_str = 'Epoch: {:3} | T_Loss {:5} | T_Acc {:5} | V_Loss {:5} | V_Acc {:5} | {:5}'.format(last(iter_log), train_loss, train_acc, val_loss, val_acc, time_spent)

    log_stack.append(log_str)

    # 학습 추이 그래프 출력
    hist_fig, loss_axis = plt.subplots(figsize=(10, 3), dpi=99)
    hist_fig.patch.set_facecolor('white')

    # Loss Line 구성
    loss_t_line = plt.plot(iter_log, tloss_log, label='Train_Loss', color='red', marker='o')
    loss_v_line = plt.plot(iter_log, vloss_log, label='Valid_Loss', color='blue', marker='s')
    loss_axis.set_xlabel('epoch')
    loss_axis.set_ylabel('loss')

    # Acc, Line 구성
    acc_axis = loss_axis.twinx()
    acc_t_line = acc_axis.plot(iter_log, tacc_log, label='Train_Acc', color='red', marker='+')
    acc_v_line = acc_axis.plot(iter_log, vacc_log, label='Valid_Acc', color='blue', marker='x')
    acc_axis.set_ylabel('accuracy')

    # 그래프 출력
    hist_lines = loss_t_line + loss_v_line + acc_t_line + acc_v_line
    loss_axis.legend(hist_lines, [l.get_label() for l in hist_lines])
    loss_axis.grid()
    plt.title('Learning history until epoch {}'.format(last(iter_log)))
    plt.draw()

    # 텍스트 로그 출력
    clear_output(wait=True)
    plt.show()
    for idx in reversed(range(len(log_stack))):
        print(log_stack[idx])

# %%
def clear_memory():
    if device != 'cpu':
        empty_cache()
    gc.collect()

# %%
# 학습 알고리즘
def epoch(data_loader, mode = 'train'):
    global epoch_cnt

    # 사용되는 변수 초기화
    iter_loss, iter_acc, last_grad_performed = [], [], False

    # 1 iteration 학습 알고리즘(for문을 나오면 1 epoch 완료)
    for _data, _label in data_loader:
        data, label = _data.to(device), _label.type(torch.LongTensor).to(device)

        # 1. Feed-forward
        if mode == 'train':
            net.train()
        else:
            # 학습때만 쓰이는 Dropout, Batch Mormalization을 미사용
            net.eval()

        result = net(data) # 1 Batch에 대한 결과가 모든 Class에 대한 확률값으로
        _, out = torch.max(result, 1) # result에서 최대 확률값을 기준으로 예측 class 도출( _ : 값 부분은 필요 없음, out : index 중 가장 큰 하나의 데이터)

        # 2. Loss 계산
        loss = loss_fn(result, label) # GT 와 Label 비교하여 Loss 산정
        iter_loss.append(loss.item()) # 학습 추이를 위하여 Loss를 기록

        # 3. 역전파 학습 후 Gradient Descent
        if mode == 'train':
            optim.zero_grad() # 미분을 통해 얻은 기울기를 초기화 for 다음 epoch
            loss.backward() # 역전파 학습
            optim.step() # Gradient Descent 수행
            last_grad_performed = True # for문을 나가면 epoch 카운터 += 1

        # 4. 정확도 계산
        acc_partial = (out == label).float().sum() # GT == Label 인 개수
        acc_partial = acc_partial / len(label) # ( TP / (TP + TM)) 해서 정확도 산출
        iter_acc.append(acc_partial.item()) # 학습 추이를 위하여 Acc. 기록

    # 역전파 학습 후 Epoch 카운터 += 1
    if last_grad_performed:
        epoch_cnt += 1

    clear_memory()

    # loss와 acc의 평균값 for 학습추이 그래프, 모든 GT와 Label 값 for 컨퓨전 매트릭스
    return np.average(iter_loss), np.average(iter_acc)

def epoch_not_finished():
    # 에폭이 끝남을 알림
    return epoch_cnt < maximum_epoch

# %%
import time
from torch.cuda import memory_allocated, empty_cache
from IPython.display import Image, clear_output
start_dot = 11      # mp.solutions.pose 시작 포인트 (0: 얼굴부터 발목까지, 11: 어깨부터 발목까지)
attention_dot = [n for n in range(start_dot, 29)]

# %%
# Training initialization
init_model()
init_epoch()
init_log()
maximum_epoch = EPOCH

# Training iteration

while epoch_not_finished():
    start_time = time.time()

    tloss, tacc = epoch(train_loader, mode = 'train')

    end_time = time.time()
    time_taken = end_time - start_time
    record_train_log(tloss, tacc, time_taken)

    with torch.no_grad():
        vloss, vacc = epoch(val_loader, mode = 'val')
        record_valid_log(vloss, vacc)

    print_log()

print('\n Training completed!')
# Out:
# Epoch: 700 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.176 | V_Acc 0.806 | 1.415
# Epoch: 699 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  2.17 | V_Acc 0.806 | 1.068
# Epoch: 698 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.164 | V_Acc 0.806 | 1.108
# Epoch: 697 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.159 | V_Acc 0.806 |  1.12
# Epoch: 696 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.153 | V_Acc 0.806 | 1.418
# Epoch: 695 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.147 | V_Acc 0.806 | 1.492
# Epoch: 694 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.141 | V_Acc 0.806 | 1.361
# Epoch: 693 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.136 | V_Acc 0.806 |  1.41
# Epoch: 692 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.129 | V_Acc 0.806 | 1.114
# Epoch: 691 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.124 | V_Acc 0.806 | 1.103
# Epoch: 690 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.118 | V_Acc 0.813 | 1.118
# Epoch: 689 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.111 | V_Acc 0.813 | 1.103
# Epoch: 688 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.106 | V_Acc 0.813 | 1.115
# Epoch: 687 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.101 | V_Acc 0.813 | 1.155
# Epoch: 686 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.096 | V_Acc 0.813 | 1.428
# Epoch: 685 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.091 | V_Acc 0.813 | 1.089
# Epoch: 684 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.085 | V_Acc 0.813 | 0.948
# Epoch: 683 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.079 | V_Acc 0.813 | 0.944
# Epoch: 682 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.073 | V_Acc 0.813 | 1.108
# Epoch: 681 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.068 | V_Acc 0.813 | 0.989
# Epoch: 680 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.063 | V_Acc 0.813 | 1.084
# Epoch: 679 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.056 | V_Acc 0.813 | 1.441
# Epoch: 678 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.051 | V_Acc 0.813 | 1.336
# Epoch: 677 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.045 | V_Acc 0.813 | 1.093
# Epoch: 676 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  2.04 | V_Acc 0.813 | 1.071
# Epoch: 675 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.034 | V_Acc 0.813 | 1.098
# Epoch: 674 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.028 | V_Acc 0.813 | 1.111
# Epoch: 673 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.023 | V_Acc 0.813 | 1.078
# Epoch: 672 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.017 | V_Acc 0.813 | 1.368
# Epoch: 671 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.012 | V_Acc 0.813 | 1.457
# Epoch: 670 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.006 | V_Acc 0.813 | 1.113
# Epoch: 669 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 2.001 | V_Acc 0.813 | 1.041
# Epoch: 668 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.995 | V_Acc 0.813 | 1.096
# Epoch: 667 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.99 | V_Acc 0.813 | 1.096
# Epoch: 666 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.985 | V_Acc 0.813 | 1.101
# Epoch: 665 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.979 | V_Acc 0.813 | 1.146
# Epoch: 664 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.973 | V_Acc 0.813 | 1.434
# Epoch: 663 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.968 | V_Acc 0.813 | 1.146
# Epoch: 662 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.963 | V_Acc 0.813 | 1.111
# Epoch: 661 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.958 | V_Acc 0.813 | 1.096
# Epoch: 660 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.952 | V_Acc 0.813 | 1.103
# Epoch: 659 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.947 | V_Acc 0.813 | 1.114
# Epoch: 658 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.942 | V_Acc 0.813 | 1.103
# Epoch: 657 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.937 | V_Acc 0.813 | 1.413
# Epoch: 656 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.931 | V_Acc 0.813 | 1.349
# Epoch: 655 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.926 | V_Acc 0.813 | 1.103
# Epoch: 654 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.92 | V_Acc 0.813 | 1.117
# Epoch: 653 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.915 | V_Acc 0.813 |  1.11
# Epoch: 652 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.91 | V_Acc 0.813 | 1.128
# Epoch: 651 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.905 | V_Acc 0.813 | 1.104
# Epoch: 650 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.899 | V_Acc 0.813 |  1.32
# Epoch: 649 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.894 | V_Acc 0.813 | 1.403
# Epoch: 648 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.888 | V_Acc 0.813 | 1.131
# Epoch: 647 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.882 | V_Acc 0.813 | 1.105
# Epoch: 646 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.877 | V_Acc 0.813 | 0.953
# Epoch: 645 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.871 | V_Acc 0.813 | 1.103
# Epoch: 644 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.866 | V_Acc 0.813 | 1.076
# Epoch: 643 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.861 | V_Acc 0.813 | 1.099
# Epoch: 642 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.856 | V_Acc 0.813 | 1.419
# Epoch: 641 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.85 | V_Acc 0.813 | 1.181
# Epoch: 640 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.845 | V_Acc 0.813 |  1.06
# Epoch: 639 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.84 | V_Acc 0.813 | 1.103
# Epoch: 638 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.834 | V_Acc 0.813 |  1.07
# Epoch: 637 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.829 | V_Acc 0.813 | 1.103
# Epoch: 636 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.824 | V_Acc 0.813 | 1.109
# Epoch: 635 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.82 | V_Acc 0.813 | 1.411
# Epoch: 634 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.814 | V_Acc 0.813 | 1.468
# Epoch: 633 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.809 | V_Acc 0.813 | 1.086
# Epoch: 632 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.804 | V_Acc 0.813 |  1.07
# Epoch: 631 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.799 | V_Acc 0.813 |   1.1
# Epoch: 630 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.794 | V_Acc 0.813 |  1.05
# Epoch: 629 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.79 | V_Acc 0.813 | 1.114
# Epoch: 628 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.784 | V_Acc 0.813 | 1.186
# Epoch: 627 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.779 | V_Acc 0.813 | 1.392
# Epoch: 626 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.774 | V_Acc 0.813 |  0.97
# Epoch: 625 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.769 | V_Acc 0.813 |   1.1
# Epoch: 624 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.765 | V_Acc 0.813 |  1.08
# Epoch: 623 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.76 | V_Acc 0.813 | 1.083
# Epoch: 622 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.754 | V_Acc 0.813 | 1.099
# Epoch: 621 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.749 | V_Acc 0.813 | 1.077
# Epoch: 620 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.744 | V_Acc 0.813 |  1.43
# Epoch: 619 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.74 | V_Acc 0.813 | 1.215
# Epoch: 618 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.734 | V_Acc 0.813 | 1.109
# Epoch: 617 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.729 | V_Acc 0.806 |  1.08
# Epoch: 616 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.724 | V_Acc 0.806 | 1.083
# Epoch: 615 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.718 | V_Acc 0.806 | 1.115
# Epoch: 614 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.712 | V_Acc 0.806 | 1.115
# Epoch: 613 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.707 | V_Acc 0.806 | 1.435
# Epoch: 612 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.702 | V_Acc 0.806 | 1.347
# Epoch: 611 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.697 | V_Acc 0.806 | 1.106
# Epoch: 610 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.692 | V_Acc 0.806 | 1.112
# Epoch: 609 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.686 | V_Acc 0.806 | 1.106
# Epoch: 608 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.681 | V_Acc 0.806 | 0.945
# Epoch: 607 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.676 | V_Acc 0.806 | 1.094
# Epoch: 606 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.67 | V_Acc 0.806 | 1.309
# Epoch: 605 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.664 | V_Acc 0.806 | 1.417
# Epoch: 604 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.659 | V_Acc 0.806 | 1.086
# Epoch: 603 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.653 | V_Acc 0.806 | 1.092
# Epoch: 602 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.648 | V_Acc 0.806 | 1.091
# Epoch: 601 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.643 | V_Acc 0.806 | 1.091
# Epoch: 600 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.637 | V_Acc 0.806 | 1.096
# Epoch: 599 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.631 | V_Acc 0.806 | 1.085
# Epoch: 598 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.625 | V_Acc 0.806 | 1.424
# Epoch: 597 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.619 | V_Acc 0.806 | 1.149
# Epoch: 596 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.613 | V_Acc 0.806 | 1.081
# Epoch: 595 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.608 | V_Acc 0.806 | 0.947
# Epoch: 594 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.602 | V_Acc 0.806 | 1.093
# Epoch: 593 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.597 | V_Acc 0.806 | 1.023
# Epoch: 592 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.591 | V_Acc 0.806 | 1.081
# Epoch: 591 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.585 | V_Acc 0.806 | 1.435
# Epoch: 590 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.579 | V_Acc 0.806 | 1.379
# Epoch: 589 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.573 | V_Acc 0.806 | 1.066
# Epoch: 588 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.567 | V_Acc 0.806 | 1.082
# Epoch: 587 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.56 | V_Acc 0.806 | 1.052
# Epoch: 586 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.555 | V_Acc 0.806 | 1.075
# Epoch: 585 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.549 | V_Acc 0.806 |  0.92
# Epoch: 584 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.543 | V_Acc 0.806 | 1.223
# Epoch: 583 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.536 | V_Acc 0.806 | 1.434
# Epoch: 582 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.53 | V_Acc 0.806 | 1.055
# Epoch: 581 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.524 | V_Acc 0.806 | 1.041
# Epoch: 580 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.518 | V_Acc 0.806 | 1.074
# Epoch: 579 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.511 | V_Acc 0.806 | 1.095
# Epoch: 578 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.503 | V_Acc 0.806 | 1.076
# Epoch: 577 | T_Loss   0.0 | T_Acc   1.0 | V_Loss 1.496 | V_Acc 0.806 | 1.093
# Epoch: 576 | T_Loss   0.0 | T_Acc   1.0 | V_Loss  1.49 | V_Acc 0.806 | 1.412
# Epoch: 575 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.482 | V_Acc 0.806 | 1.172
# Epoch: 574 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.475 | V_Acc 0.806 | 1.054
# Epoch: 573 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.468 | V_Acc 0.806 | 1.048
# Epoch: 572 | T_Loss 0.001 | T_Acc   1.0 | V_Loss  1.46 | V_Acc 0.806 |  1.08
# Epoch: 571 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.452 | V_Acc 0.806 | 1.087
# Epoch: 570 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.443 | V_Acc 0.806 | 1.073
# Epoch: 569 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.433 | V_Acc   0.8 | 1.402
# Epoch: 568 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.424 | V_Acc   0.8 | 1.421
# Epoch: 567 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.414 | V_Acc   0.8 | 1.082
# Epoch: 566 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.405 | V_Acc   0.8 | 1.103
# Epoch: 565 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.397 | V_Acc   0.8 | 1.092
# Epoch: 564 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.385 | V_Acc   0.8 |  1.06
# Epoch: 563 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.374 | V_Acc   0.8 | 1.067
# Epoch: 562 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.363 | V_Acc   0.8 | 1.124
# Epoch: 561 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.349 | V_Acc   0.8 | 1.384
# Epoch: 560 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.336 | V_Acc   0.8 | 1.089
# Epoch: 559 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.323 | V_Acc   0.8 | 1.062
# Epoch: 558 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.307 | V_Acc   0.8 | 0.963
# Epoch: 557 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.291 | V_Acc   0.8 | 1.074
# Epoch: 556 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.273 | V_Acc   0.8 | 1.036
# Epoch: 555 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.256 | V_Acc   0.8 | 1.082
# Epoch: 554 | T_Loss 0.003 | T_Acc 0.999 | V_Loss  1.24 | V_Acc   0.8 | 1.381
# Epoch: 553 | T_Loss 0.006 | T_Acc 0.998 | V_Loss 1.169 | V_Acc   0.8 |  1.24
# Epoch: 552 | T_Loss 0.003 | T_Acc 0.999 | V_Loss 1.192 | V_Acc   0.8 | 1.078
# Epoch: 551 | T_Loss 0.009 | T_Acc 0.997 | V_Loss 1.143 | V_Acc   0.8 | 1.083
# Epoch: 550 | T_Loss 0.005 | T_Acc 0.999 | V_Loss 1.094 | V_Acc 0.813 | 1.072
# Epoch: 549 | T_Loss 0.004 | T_Acc   1.0 | V_Loss 1.097 | V_Acc 0.806 | 1.105
# Epoch: 548 | T_Loss 0.017 | T_Acc 0.998 | V_Loss 0.997 | V_Acc 0.825 | 1.028
# Epoch: 547 | T_Loss  0.03 | T_Acc 0.992 | V_Loss  1.08 | V_Acc 0.781 | 1.181
# Epoch: 546 | T_Loss 0.074 | T_Acc 0.973 | V_Loss 1.053 | V_Acc 0.781 | 1.406
# Epoch: 545 | T_Loss 0.037 | T_Acc 0.986 | V_Loss 0.952 | V_Acc 0.788 | 1.094
# Epoch: 544 | T_Loss 0.027 | T_Acc 0.993 | V_Loss 0.936 | V_Acc 0.819 | 1.076
# Epoch: 543 | T_Loss 0.086 | T_Acc 0.974 | V_Loss 0.869 | V_Acc 0.794 | 1.081
# Epoch: 542 | T_Loss 0.044 | T_Acc 0.984 | V_Loss 1.282 | V_Acc  0.75 | 1.076
# Epoch: 541 | T_Loss 0.029 | T_Acc 0.989 | V_Loss 0.964 | V_Acc 0.794 | 1.072
# Epoch: 540 | T_Loss 0.031 | T_Acc 0.989 | V_Loss 0.982 | V_Acc 0.813 | 1.073
# Epoch: 539 | T_Loss 0.041 | T_Acc 0.989 | V_Loss 1.112 | V_Acc 0.769 | 1.418
# Epoch: 538 | T_Loss 0.052 | T_Acc 0.985 | V_Loss  0.98 | V_Acc 0.769 | 1.289
# Epoch: 537 | T_Loss 0.016 | T_Acc 0.996 | V_Loss  1.15 | V_Acc 0.744 | 1.068
# Epoch: 536 | T_Loss 0.019 | T_Acc 0.995 | V_Loss 1.098 | V_Acc 0.763 | 1.066
# Epoch: 535 | T_Loss 0.041 | T_Acc 0.989 | V_Loss 0.976 | V_Acc  0.75 |  1.06
# Epoch: 534 | T_Loss 0.075 | T_Acc 0.974 | V_Loss  0.97 | V_Acc 0.775 | 1.032
# Epoch: 533 | T_Loss 0.114 | T_Acc 0.966 | V_Loss   0.9 | V_Acc 0.831 |  1.04
# Epoch: 532 | T_Loss 0.078 | T_Acc 0.978 | V_Loss 1.202 | V_Acc 0.744 |  1.29
# Epoch: 531 | T_Loss  0.04 | T_Acc 0.983 | V_Loss 1.293 | V_Acc 0.769 | 1.427
# Epoch: 530 | T_Loss 0.019 | T_Acc 0.993 | V_Loss 1.178 | V_Acc 0.781 | 1.079
# Epoch: 529 | T_Loss 0.011 | T_Acc 0.996 | V_Loss 1.158 | V_Acc 0.806 | 1.066
# Epoch: 528 | T_Loss 0.011 | T_Acc 0.997 | V_Loss  1.16 | V_Acc 0.806 | 1.075
# Epoch: 527 | T_Loss 0.009 | T_Acc 0.998 | V_Loss 1.133 | V_Acc 0.794 | 1.041
# Epoch: 526 | T_Loss  0.01 | T_Acc 0.996 | V_Loss 1.181 | V_Acc   0.8 |  1.09
# Epoch: 525 | T_Loss 0.006 | T_Acc 0.999 | V_Loss 1.099 | V_Acc 0.794 | 1.074
# Epoch: 524 | T_Loss 0.007 | T_Acc 0.999 | V_Loss 1.093 | V_Acc 0.775 | 1.402
# Epoch: 523 | T_Loss  0.01 | T_Acc 0.998 | V_Loss 1.074 | V_Acc 0.788 | 1.268
# Epoch: 522 | T_Loss 0.027 | T_Acc 0.992 | V_Loss 0.943 | V_Acc 0.794 | 1.072
# Epoch: 521 | T_Loss 0.093 | T_Acc 0.971 | V_Loss 0.883 | V_Acc   0.8 | 1.066
# Epoch: 520 | T_Loss 0.058 | T_Acc  0.98 | V_Loss 1.029 | V_Acc 0.769 | 1.066
# Epoch: 519 | T_Loss 0.021 | T_Acc 0.993 | V_Loss 1.012 | V_Acc 0.775 | 1.027
# Epoch: 518 | T_Loss 0.056 | T_Acc 0.985 | V_Loss 0.885 | V_Acc 0.781 | 1.029
# Epoch: 517 | T_Loss 0.088 | T_Acc 0.969 | V_Loss 0.813 | V_Acc   0.8 |  1.25
# Epoch: 516 | T_Loss  0.32 | T_Acc 0.875 | V_Loss 0.735 | V_Acc 0.788 | 1.445
# Epoch: 515 | T_Loss 0.048 | T_Acc 0.989 | V_Loss 1.297 | V_Acc 0.738 | 1.066
# Epoch: 514 | T_Loss 0.004 | T_Acc 0.999 | V_Loss 1.217 | V_Acc   0.8 | 1.063
# Epoch: 513 | T_Loss 0.005 | T_Acc 0.998 | V_Loss 1.182 | V_Acc   0.8 | 1.065
# Epoch: 512 | T_Loss 0.006 | T_Acc 0.998 | V_Loss  1.17 | V_Acc 0.806 | 1.062
# Epoch: 511 | T_Loss 0.008 | T_Acc 0.997 | V_Loss 1.147 | V_Acc 0.788 | 1.071
# Epoch: 510 | T_Loss 0.009 | T_Acc 0.997 | V_Loss 1.106 | V_Acc 0.806 | 1.071
# Epoch: 509 | T_Loss 0.007 | T_Acc 0.998 | V_Loss 1.085 | V_Acc   0.8 |  1.42
# Epoch: 508 | T_Loss  0.01 | T_Acc 0.998 | V_Loss 1.066 | V_Acc 0.806 | 1.314
# Epoch: 507 | T_Loss 0.012 | T_Acc 0.998 | V_Loss 1.029 | V_Acc 0.806 | 1.071
# Epoch: 506 | T_Loss 0.017 | T_Acc 0.997 | V_Loss 0.952 | V_Acc 0.825 | 1.098
# Epoch: 505 | T_Loss 0.041 | T_Acc 0.989 | V_Loss 0.859 | V_Acc 0.794 | 1.382
# Epoch: 504 | T_Loss 0.135 | T_Acc 0.947 | V_Loss   0.8 | V_Acc 0.788 | 0.965
# Epoch: 503 | T_Loss 0.165 | T_Acc 0.942 | V_Loss 0.852 | V_Acc 0.775 | 1.068
# Epoch: 502 | T_Loss 0.062 | T_Acc 0.977 | V_Loss  0.96 | V_Acc   0.8 | 1.405
# Epoch: 501 | T_Loss  0.03 | T_Acc  0.99 | V_Loss 0.964 | V_Acc 0.813 |  1.27
# Epoch: 500 | T_Loss 0.032 | T_Acc 0.989 | V_Loss 0.908 | V_Acc 0.775 | 0.955
# Epoch: 499 | T_Loss 0.041 | T_Acc 0.989 | V_Loss 1.007 | V_Acc 0.769 | 1.064
# Epoch: 498 | T_Loss 0.066 | T_Acc  0.98 | V_Loss 1.009 | V_Acc 0.731 | 1.062
# Epoch: 497 | T_Loss  0.13 | T_Acc 0.956 | V_Loss  0.81 | V_Acc 0.769 | 0.938
# Epoch: 496 | T_Loss 0.068 | T_Acc 0.972 | V_Loss 1.181 | V_Acc 0.756 | 1.075
# Epoch: 495 | T_Loss 0.039 | T_Acc 0.987 | V_Loss 0.952 | V_Acc 0.763 | 1.235
# Epoch: 494 | T_Loss 0.035 | T_Acc 0.989 | V_Loss 0.878 | V_Acc 0.819 | 1.378
# Epoch: 493 | T_Loss 0.077 | T_Acc 0.978 | V_Loss 0.811 | V_Acc   0.8 | 1.055
# Epoch: 492 | T_Loss 0.166 | T_Acc 0.944 | V_Loss 0.736 | V_Acc 0.813 | 1.067
# Epoch: 491 | T_Loss 0.076 | T_Acc 0.976 | V_Loss 0.887 | V_Acc 0.813 | 1.065
# Epoch: 490 | T_Loss 0.073 | T_Acc 0.974 | V_Loss 0.945 | V_Acc   0.8 | 1.063
# Epoch: 489 | T_Loss 0.144 | T_Acc 0.949 | V_Loss 0.857 | V_Acc 0.788 | 1.056
# Epoch: 488 | T_Loss 0.096 | T_Acc 0.974 | V_Loss 0.873 | V_Acc   0.8 | 1.059
# Epoch: 487 | T_Loss 0.013 | T_Acc 0.997 | V_Loss 1.191 | V_Acc 0.806 | 1.431
# Epoch: 486 | T_Loss  0.02 | T_Acc 0.996 | V_Loss 1.238 | V_Acc 0.794 | 1.287
# Epoch: 485 | T_Loss 0.014 | T_Acc 0.997 | V_Loss 1.181 | V_Acc 0.775 | 1.069
# Epoch: 484 | T_Loss 0.018 | T_Acc 0.997 | V_Loss 1.144 | V_Acc 0.781 | 1.071
# Epoch: 483 | T_Loss 0.033 | T_Acc 0.991 | V_Loss 1.104 | V_Acc 0.775 | 1.051
# Epoch: 482 | T_Loss 0.056 | T_Acc 0.983 | V_Loss 1.087 | V_Acc 0.781 | 1.065
# Epoch: 481 | T_Loss 0.056 | T_Acc 0.981 | V_Loss 0.926 | V_Acc 0.813 | 1.051
# Epoch: 480 | T_Loss 0.099 | T_Acc 0.965 | V_Loss 1.016 | V_Acc 0.769 | 1.136
# Epoch: 479 | T_Loss 0.082 | T_Acc 0.971 | V_Loss 1.151 | V_Acc   0.7 | 1.366
# Epoch: 478 | T_Loss 0.084 | T_Acc  0.97 | V_Loss 0.998 | V_Acc 0.775 | 1.078
# Epoch: 477 | T_Loss 0.045 | T_Acc 0.984 | V_Loss 0.934 | V_Acc 0.813 | 1.049
# Epoch: 476 | T_Loss  0.04 | T_Acc 0.989 | V_Loss 0.977 | V_Acc 0.775 | 1.068
# Epoch: 475 | T_Loss 0.046 | T_Acc 0.989 | V_Loss 0.902 | V_Acc   0.8 | 1.051
# Epoch: 474 | T_Loss 0.121 | T_Acc 0.956 | V_Loss 0.794 | V_Acc 0.813 | 0.963
# Epoch: 473 | T_Loss 0.158 | T_Acc 0.939 | V_Loss 0.987 | V_Acc  0.75 | 1.063
# Epoch: 472 | T_Loss 0.085 | T_Acc 0.973 | V_Loss 1.046 | V_Acc 0.769 | 1.383
# Epoch: 471 | T_Loss 0.067 | T_Acc  0.98 | V_Loss 0.884 | V_Acc 0.794 | 1.368
# Epoch: 470 | T_Loss 0.075 | T_Acc 0.972 | V_Loss 0.995 | V_Acc 0.775 | 1.056
# Epoch: 469 | T_Loss 0.072 | T_Acc 0.973 | V_Loss 0.949 | V_Acc 0.744 | 1.041
# Epoch: 468 | T_Loss 0.105 | T_Acc 0.966 | V_Loss 0.903 | V_Acc 0.781 | 1.053
# Epoch: 467 | T_Loss 0.123 | T_Acc 0.961 | V_Loss 0.867 | V_Acc 0.775 | 1.024
# Epoch: 466 | T_Loss  0.11 | T_Acc 0.961 | V_Loss  0.97 | V_Acc 0.756 | 1.047
# Epoch: 465 | T_Loss 0.083 | T_Acc 0.971 | V_Loss 0.756 | V_Acc 0.806 | 0.952
# Epoch: 464 | T_Loss 0.125 | T_Acc 0.955 | V_Loss  0.73 | V_Acc 0.781 | 1.374
# Epoch: 463 | T_Loss 0.151 | T_Acc 0.943 | V_Loss 0.766 | V_Acc 0.769 | 1.154
# Epoch: 462 | T_Loss 0.136 | T_Acc 0.957 | V_Loss 0.767 | V_Acc 0.775 | 1.059
# Epoch: 461 | T_Loss 0.126 | T_Acc 0.959 | V_Loss 0.866 | V_Acc 0.719 |  1.05
# Epoch: 460 | T_Loss 0.134 | T_Acc 0.957 | V_Loss 0.855 | V_Acc 0.756 | 1.027
# Epoch: 459 | T_Loss 0.134 | T_Acc 0.953 | V_Loss 0.798 | V_Acc 0.744 | 1.038
# Epoch: 458 | T_Loss 0.143 | T_Acc 0.949 | V_Loss 0.807 | V_Acc 0.794 | 1.057
# Epoch: 457 | T_Loss 0.158 | T_Acc 0.952 | V_Loss 0.792 | V_Acc 0.781 | 1.263
# Epoch: 456 | T_Loss 0.145 | T_Acc  0.95 | V_Loss 0.905 | V_Acc 0.731 |  1.38
# Epoch: 455 | T_Loss 0.171 | T_Acc 0.936 | V_Loss 0.768 | V_Acc  0.75 | 1.057
# Epoch: 454 | T_Loss  0.22 | T_Acc  0.92 | V_Loss 0.729 | V_Acc 0.781 | 1.049
# Epoch: 453 | T_Loss 0.136 | T_Acc 0.954 | V_Loss 0.738 | V_Acc 0.763 | 1.045
# Epoch: 452 | T_Loss 0.159 | T_Acc  0.94 | V_Loss 0.634 | V_Acc 0.813 | 1.051
# Epoch: 451 | T_Loss 0.193 | T_Acc  0.93 | V_Loss 0.727 | V_Acc 0.744 |  1.05
# Epoch: 450 | T_Loss 0.246 | T_Acc 0.906 | V_Loss 0.686 | V_Acc 0.763 | 1.039
# Epoch: 449 | T_Loss 0.299 | T_Acc 0.875 | V_Loss 0.572 | V_Acc 0.794 | 1.403
# Epoch: 448 | T_Loss 0.232 | T_Acc 0.908 | V_Loss 0.607 | V_Acc 0.781 | 1.294
# Epoch: 447 | T_Loss 0.321 | T_Acc 0.875 | V_Loss 0.542 | V_Acc 0.775 | 1.048
# Epoch: 446 | T_Loss 0.247 | T_Acc 0.912 | V_Loss 0.666 | V_Acc 0.731 | 1.057
# Epoch: 445 | T_Loss 0.247 | T_Acc 0.895 | V_Loss 0.551 | V_Acc 0.806 | 1.042
# Epoch: 444 | T_Loss 0.249 | T_Acc 0.903 | V_Loss 0.562 | V_Acc 0.788 | 1.038
# Epoch: 443 | T_Loss 0.273 | T_Acc 0.898 | V_Loss 0.557 | V_Acc 0.781 |  1.06
# Epoch: 442 | T_Loss 0.266 | T_Acc   0.9 | V_Loss 0.605 | V_Acc 0.769 | 1.115
# Epoch: 441 | T_Loss 0.293 | T_Acc 0.884 | V_Loss 0.565 | V_Acc 0.788 |  1.37
# Epoch: 440 | T_Loss 0.302 | T_Acc 0.885 | V_Loss 0.566 | V_Acc 0.756 | 0.997
# Epoch: 439 | T_Loss 0.318 | T_Acc 0.872 | V_Loss 0.535 | V_Acc 0.781 |  1.05
# Epoch: 438 | T_Loss 0.311 | T_Acc 0.875 | V_Loss 0.585 | V_Acc 0.756 | 1.059
# Epoch: 437 | T_Loss 0.305 | T_Acc 0.867 | V_Loss 0.553 | V_Acc 0.813 | 1.056
# Epoch: 436 | T_Loss 0.322 | T_Acc  0.87 | V_Loss  0.54 | V_Acc   0.8 | 1.055
# Epoch: 435 | T_Loss 0.353 | T_Acc 0.848 | V_Loss 0.495 | V_Acc 0.813 | 1.037
# Epoch: 434 | T_Loss 0.358 | T_Acc 0.849 | V_Loss 0.511 | V_Acc 0.806 | 1.401
# Epoch: 433 | T_Loss 0.374 | T_Acc 0.828 | V_Loss 0.474 | V_Acc 0.813 | 1.381
# Epoch: 432 | T_Loss  0.39 | T_Acc 0.822 | V_Loss 0.483 | V_Acc 0.788 | 1.048
# Epoch: 431 | T_Loss 0.415 | T_Acc 0.797 | V_Loss 0.483 | V_Acc 0.788 | 1.048
# Epoch: 430 | T_Loss 0.416 | T_Acc 0.805 | V_Loss 0.462 | V_Acc 0.794 |  1.02
# Epoch: 429 | T_Loss 0.418 | T_Acc 0.802 | V_Loss 0.491 | V_Acc 0.781 | 1.048
# Epoch: 428 | T_Loss 0.437 | T_Acc 0.786 | V_Loss 0.486 | V_Acc 0.788 | 1.052
# Epoch: 427 | T_Loss 0.468 | T_Acc 0.776 | V_Loss 0.489 | V_Acc 0.731 |  1.03
# Epoch: 426 | T_Loss 0.492 | T_Acc 0.753 | V_Loss 0.477 | V_Acc 0.769 | 1.374
# Epoch: 425 | T_Loss 0.524 | T_Acc 0.741 | V_Loss 0.519 | V_Acc 0.738 | 1.248
# Epoch: 424 | T_Loss 0.583 | T_Acc  0.71 | V_Loss 0.541 | V_Acc 0.706 | 1.038
# Epoch: 423 | T_Loss 0.567 | T_Acc 0.843 | V_Loss 0.616 | V_Acc 0.663 | 1.033
# Epoch: 422 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.255 | V_Acc 0.844 | 1.048
# Epoch: 421 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.298 | V_Acc 0.838 | 1.034
# Epoch: 420 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.281 | V_Acc 0.838 | 1.035
# Epoch: 419 | T_Loss 0.001 | T_Acc   1.0 | V_Loss  1.27 | V_Acc 0.838 | 1.101
# Epoch: 418 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.264 | V_Acc 0.838 | 1.365
# Epoch: 417 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.251 | V_Acc 0.838 | 1.057
# Epoch: 416 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.249 | V_Acc 0.838 | 0.971
# Epoch: 415 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.246 | V_Acc 0.838 | 1.036
# Epoch: 414 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.238 | V_Acc 0.838 | 1.039
# Epoch: 413 | T_Loss 0.001 | T_Acc   1.0 | V_Loss  1.23 | V_Acc 0.838 | 1.041
# Epoch: 412 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.227 | V_Acc 0.838 | 1.026
# Epoch: 411 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.219 | V_Acc 0.838 | 1.359
# Epoch: 410 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.213 | V_Acc 0.838 |  1.37
# Epoch: 409 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.207 | V_Acc 0.838 | 1.045
# Epoch: 408 | T_Loss 0.001 | T_Acc   1.0 | V_Loss 1.206 | V_Acc 0.838 | 1.025
# Epoch: 407 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.199 | V_Acc 0.838 | 1.031
# Epoch: 406 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.194 | V_Acc 0.838 | 1.035
# Epoch: 405 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.185 | V_Acc 0.838 | 0.995
# Epoch: 404 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.183 | V_Acc 0.838 | 0.938
# Epoch: 403 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.175 | V_Acc 0.838 | 1.375
# Epoch: 402 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.169 | V_Acc 0.838 | 1.146
# Epoch: 401 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.165 | V_Acc 0.838 | 1.047
# Epoch: 400 | T_Loss 0.002 | T_Acc   1.0 | V_Loss  1.16 | V_Acc 0.838 |  1.04
# Epoch: 399 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.157 | V_Acc 0.838 |  1.04
# Epoch: 398 | T_Loss 0.002 | T_Acc   1.0 | V_Loss 1.155 | V_Acc 0.838 |  1.05
# Epoch: 397 | T_Loss 0.002 | T_Acc 0.999 | V_Loss 1.148 | V_Acc 0.838 | 1.054
# Epoch: 396 | T_Loss 0.002 | T_Acc 0.999 | V_Loss 1.146 | V_Acc 0.844 | 1.301
# Epoch: 395 | T_Loss 0.002 | T_Acc 0.999 | V_Loss  1.14 | V_Acc 0.844 | 1.352
# Epoch: 394 | T_Loss 0.002 | T_Acc 0.998 | V_Loss 1.135 | V_Acc 0.844 | 1.037
# Epoch: 393 | T_Loss 0.002 | T_Acc 0.998 | V_Loss 1.132 | V_Acc 0.844 | 1.051
# Epoch: 392 | T_Loss 0.002 | T_Acc 0.998 | V_Loss 1.127 | V_Acc 0.844 | 1.042
# Epoch: 391 | T_Loss 0.002 | T_Acc 0.998 | V_Loss 1.123 | V_Acc 0.844 | 1.034
# Epoch: 390 | T_Loss 0.002 | T_Acc 0.998 | V_Loss 1.117 | V_Acc 0.844 | 1.041
# Epoch: 389 | T_Loss 0.002 | T_Acc 0.998 | V_Loss  1.11 | V_Acc 0.844 | 1.027
# Epoch: 388 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.104 | V_Acc 0.844 | 1.358
# Epoch: 387 | T_Loss 0.002 | T_Acc 0.998 | V_Loss   1.1 | V_Acc 0.844 | 1.187
# Epoch: 386 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.093 | V_Acc 0.844 | 1.026
# Epoch: 385 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.087 | V_Acc 0.844 | 1.027
# Epoch: 384 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.081 | V_Acc 0.844 | 1.035
# Epoch: 383 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.078 | V_Acc 0.844 | 1.023
# Epoch: 382 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.071 | V_Acc 0.844 | 1.028
# Epoch: 381 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.067 | V_Acc 0.844 | 1.128
# Epoch: 380 | T_Loss 0.003 | T_Acc 0.998 | V_Loss  1.06 | V_Acc 0.844 | 1.377
# Epoch: 379 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.053 | V_Acc 0.844 |  1.02
# Epoch: 378 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.049 | V_Acc 0.844 | 0.993
# Epoch: 377 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.039 | V_Acc 0.844 | 1.031
# Epoch: 376 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.039 | V_Acc 0.844 | 1.034
# Epoch: 375 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.033 | V_Acc 0.844 |  1.03
# Epoch: 374 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.027 | V_Acc 0.844 |  0.96
# Epoch: 373 | T_Loss 0.003 | T_Acc 0.998 | V_Loss 1.016 | V_Acc 0.838 | 1.345
# Epoch: 372 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 1.008 | V_Acc 0.831 | 1.365
# Epoch: 371 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 1.001 | V_Acc 0.831 | 1.014
# Epoch: 370 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 0.995 | V_Acc 0.831 | 1.017
# Epoch: 369 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 0.986 | V_Acc 0.831 | 1.031
# Epoch: 368 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 0.978 | V_Acc 0.831 | 1.027
# Epoch: 367 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 0.967 | V_Acc 0.831 | 1.028
# Epoch: 366 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 0.962 | V_Acc 0.831 | 1.015
# Epoch: 365 | T_Loss 0.004 | T_Acc 0.998 | V_Loss 0.953 | V_Acc 0.831 | 1.355
# Epoch: 364 | T_Loss 0.004 | T_Acc 0.998 | V_Loss  0.94 | V_Acc 0.831 | 1.246
# Epoch: 363 | T_Loss 0.005 | T_Acc 0.998 | V_Loss  0.93 | V_Acc 0.831 | 1.061
# Epoch: 362 | T_Loss 0.005 | T_Acc 0.998 | V_Loss 0.921 | V_Acc 0.831 | 1.033
# Epoch: 361 | T_Loss 0.005 | T_Acc 0.998 | V_Loss  0.91 | V_Acc 0.831 | 1.022
# Epoch: 360 | T_Loss 0.006 | T_Acc 0.998 | V_Loss 0.895 | V_Acc 0.831 | 1.007
# Epoch: 359 | T_Loss 0.006 | T_Acc 0.998 | V_Loss 0.884 | V_Acc 0.838 | 1.023
# Epoch: 358 | T_Loss 0.006 | T_Acc 0.998 | V_Loss 0.869 | V_Acc 0.838 | 1.115
# Epoch: 357 | T_Loss 0.006 | T_Acc 0.998 | V_Loss 0.855 | V_Acc 0.838 | 1.367
# Epoch: 356 | T_Loss 0.007 | T_Acc 0.998 | V_Loss 0.834 | V_Acc 0.838 | 1.045
# Epoch: 355 | T_Loss 0.009 | T_Acc 0.997 | V_Loss 0.788 | V_Acc 0.844 | 1.017
# Epoch: 354 | T_Loss 0.011 | T_Acc 0.997 | V_Loss 0.812 | V_Acc 0.831 | 0.991
# Epoch: 353 | T_Loss 0.013 | T_Acc 0.996 | V_Loss 0.857 | V_Acc 0.819 | 1.019
# Epoch: 352 | T_Loss 0.014 | T_Acc 0.996 | V_Loss   0.8 | V_Acc 0.831 | 1.024
# Epoch: 351 | T_Loss  0.03 | T_Acc 0.993 | V_Loss 0.786 | V_Acc 0.825 | 1.056
# Epoch: 350 | T_Loss 0.061 | T_Acc 0.976 | V_Loss 0.757 | V_Acc 0.831 | 1.303
# Epoch: 349 | T_Loss 0.046 | T_Acc 0.984 | V_Loss 0.789 | V_Acc 0.825 | 1.359
# Epoch: 348 | T_Loss 0.121 | T_Acc 0.962 | V_Loss 0.767 | V_Acc 0.806 |  1.03
# Epoch: 347 | T_Loss 0.133 | T_Acc 0.955 | V_Loss 0.679 | V_Acc 0.844 | 1.001
# Epoch: 346 | T_Loss 0.053 | T_Acc 0.981 | V_Loss 0.905 | V_Acc 0.788 | 1.048
# Epoch: 345 | T_Loss 0.032 | T_Acc 0.989 | V_Loss 0.865 | V_Acc 0.806 | 1.022
# Epoch: 344 | T_Loss 0.064 | T_Acc 0.981 | V_Loss 0.793 | V_Acc 0.844 | 1.007
# Epoch: 343 | T_Loss 0.047 | T_Acc 0.984 | V_Loss 0.889 | V_Acc 0.813 | 1.017
# Epoch: 342 | T_Loss 0.034 | T_Acc 0.989 | V_Loss  0.78 | V_Acc   0.8 | 1.369
# Epoch: 341 | T_Loss 0.054 | T_Acc 0.981 | V_Loss 0.777 | V_Acc 0.831 | 1.265
# Epoch: 340 | T_Loss 0.045 | T_Acc 0.984 | V_Loss  0.68 | V_Acc 0.844 | 1.026
# Epoch: 339 | T_Loss 0.067 | T_Acc 0.979 | V_Loss 0.726 | V_Acc 0.825 |  1.01
# Epoch: 338 | T_Loss 0.093 | T_Acc 0.969 | V_Loss 0.751 | V_Acc 0.825 | 0.966
# Epoch: 337 | T_Loss 0.056 | T_Acc 0.984 | V_Loss 0.696 | V_Acc 0.844 | 1.035
# Epoch: 336 | T_Loss 0.035 | T_Acc 0.988 | V_Loss 0.908 | V_Acc 0.819 | 1.021
# Epoch: 335 | T_Loss  0.04 | T_Acc 0.985 | V_Loss 0.733 | V_Acc 0.813 | 1.014
# Epoch: 334 | T_Loss 0.042 | T_Acc 0.986 | V_Loss 0.699 | V_Acc 0.831 |  1.34
# Epoch: 333 | T_Loss 0.048 | T_Acc 0.989 | V_Loss 0.626 | V_Acc 0.856 | 1.115
# Epoch: 332 | T_Loss 0.077 | T_Acc 0.977 | V_Loss 0.664 | V_Acc 0.831 | 1.029
# Epoch: 331 | T_Loss 0.122 | T_Acc 0.959 | V_Loss 0.832 | V_Acc   0.8 | 1.003
# Epoch: 330 | T_Loss 0.256 | T_Acc 0.917 | V_Loss 0.659 | V_Acc 0.794 | 1.015
# Epoch: 329 | T_Loss 0.101 | T_Acc 0.969 | V_Loss 0.928 | V_Acc 0.763 | 1.005
# Epoch: 328 | T_Loss 0.051 | T_Acc 0.984 | V_Loss 0.931 | V_Acc 0.838 | 1.023
# Epoch: 327 | T_Loss 0.044 | T_Acc 0.987 | V_Loss  0.84 | V_Acc 0.813 | 1.198
# Epoch: 326 | T_Loss  0.05 | T_Acc 0.986 | V_Loss 0.827 | V_Acc 0.794 | 1.314
# Epoch: 325 | T_Loss 0.092 | T_Acc 0.972 | V_Loss 0.753 | V_Acc 0.819 | 1.022
# Epoch: 324 | T_Loss 0.076 | T_Acc 0.975 | V_Loss 0.674 | V_Acc 0.825 | 1.026
# Epoch: 323 | T_Loss 0.098 | T_Acc 0.966 | V_Loss 0.885 | V_Acc 0.775 | 1.025
# Epoch: 322 | T_Loss 0.045 | T_Acc 0.984 | V_Loss 0.984 | V_Acc 0.781 |  1.01
# Epoch: 321 | T_Loss 0.053 | T_Acc  0.98 | V_Loss 0.877 | V_Acc 0.788 | 1.009
# Epoch: 320 | T_Loss 0.052 | T_Acc 0.981 | V_Loss 0.932 | V_Acc 0.788 | 1.016
# Epoch: 319 | T_Loss 0.063 | T_Acc 0.981 | V_Loss 0.919 | V_Acc 0.788 | 1.361
# Epoch: 318 | T_Loss 0.075 | T_Acc 0.971 | V_Loss 0.766 | V_Acc 0.838 | 1.337
# Epoch: 317 | T_Loss 0.068 | T_Acc  0.98 | V_Loss 0.682 | V_Acc 0.825 | 0.998
# Epoch: 316 | T_Loss 0.075 | T_Acc  0.98 | V_Loss 0.666 | V_Acc 0.806 | 0.976
# Epoch: 315 | T_Loss 0.095 | T_Acc 0.973 | V_Loss 0.644 | V_Acc 0.819 | 1.011
# Epoch: 314 | T_Loss 0.138 | T_Acc 0.965 | V_Loss 0.585 | V_Acc   0.8 | 1.012
# Epoch: 313 | T_Loss 0.232 | T_Acc 0.916 | V_Loss 0.576 | V_Acc 0.806 | 1.002
# Epoch: 312 | T_Loss 0.586 | T_Acc 0.774 | V_Loss 0.581 | V_Acc 0.769 | 1.087
# Epoch: 311 | T_Loss  0.11 | T_Acc 0.958 | V_Loss  1.02 | V_Acc  0.75 | 1.583
# Epoch: 310 | T_Loss 0.047 | T_Acc 0.984 | V_Loss 1.021 | V_Acc 0.788 |  1.57
# Epoch: 309 | T_Loss 0.042 | T_Acc 0.986 | V_Loss 0.932 | V_Acc 0.794 | 1.014
# Epoch: 308 | T_Loss 0.066 | T_Acc 0.981 | V_Loss 0.884 | V_Acc 0.788 | 1.007
# Epoch: 307 | T_Loss   0.1 | T_Acc 0.966 | V_Loss 1.113 | V_Acc 0.775 |  1.01
# Epoch: 306 | T_Loss 0.063 | T_Acc 0.977 | V_Loss 0.863 | V_Acc 0.806 | 1.024
# Epoch: 305 | T_Loss  0.06 | T_Acc 0.983 | V_Loss  0.94 | V_Acc 0.813 | 1.001
# Epoch: 304 | T_Loss 0.057 | T_Acc 0.981 | V_Loss 0.845 | V_Acc 0.844 | 1.021
# Epoch: 303 | T_Loss 0.043 | T_Acc 0.984 | V_Loss  0.82 | V_Acc 0.825 | 1.262
# Epoch: 302 | T_Loss 0.055 | T_Acc 0.984 | V_Loss 0.934 | V_Acc 0.806 | 1.311
# Epoch: 301 | T_Loss 0.076 | T_Acc 0.974 | V_Loss 0.753 | V_Acc 0.838 | 1.011
# Epoch: 300 | T_Loss 0.114 | T_Acc 0.957 | V_Loss 0.541 | V_Acc 0.863 | 1.004
# Epoch: 299 | T_Loss 0.062 | T_Acc 0.978 | V_Loss 0.724 | V_Acc 0.825 |  1.01
# Epoch: 298 | T_Loss 0.059 | T_Acc 0.981 | V_Loss 0.804 | V_Acc 0.763 | 0.999
# Epoch: 297 | T_Loss 0.078 | T_Acc 0.976 | V_Loss 0.873 | V_Acc 0.781 | 1.014
# Epoch: 296 | T_Loss 0.055 | T_Acc 0.982 | V_Loss 0.713 | V_Acc 0.825 | 1.006
# Epoch: 295 | T_Loss 0.069 | T_Acc 0.974 | V_Loss 0.715 | V_Acc 0.806 | 1.299
# Epoch: 294 | T_Loss 0.111 | T_Acc 0.966 | V_Loss  0.72 | V_Acc 0.831 | 1.328
# Epoch: 293 | T_Loss 0.111 | T_Acc 0.962 | V_Loss 0.692 | V_Acc 0.806 | 1.008
# Epoch: 292 | T_Loss 0.142 | T_Acc  0.95 | V_Loss 0.862 | V_Acc 0.788 | 1.016
# Epoch: 291 | T_Loss 0.082 | T_Acc  0.97 | V_Loss 0.776 | V_Acc 0.825 | 1.002
# Epoch: 290 | T_Loss 0.076 | T_Acc 0.978 | V_Loss 0.812 | V_Acc 0.813 | 1.039
# Epoch: 289 | T_Loss 0.093 | T_Acc 0.961 | V_Loss 0.822 | V_Acc 0.813 | 1.001
# Epoch: 288 | T_Loss 0.137 | T_Acc 0.945 | V_Loss 0.831 | V_Acc 0.794 | 1.005
# Epoch: 287 | T_Loss 0.065 | T_Acc 0.977 | V_Loss 0.839 | V_Acc 0.788 | 1.365
# Epoch: 286 | T_Loss 0.053 | T_Acc 0.987 | V_Loss 0.833 | V_Acc 0.794 | 1.355
# Epoch: 285 | T_Loss 0.073 | T_Acc 0.974 | V_Loss  0.76 | V_Acc 0.806 | 0.959
# Epoch: 284 | T_Loss 0.066 | T_Acc  0.98 | V_Loss 0.825 | V_Acc 0.819 | 1.001
# Epoch: 283 | T_Loss 0.065 | T_Acc 0.976 | V_Loss 0.799 | V_Acc 0.819 | 0.992
# Epoch: 282 | T_Loss  0.09 | T_Acc 0.968 | V_Loss 0.712 | V_Acc   0.8 | 0.996
# Epoch: 281 | T_Loss 0.096 | T_Acc 0.968 | V_Loss 0.655 | V_Acc 0.819 | 1.006
# Epoch: 280 | T_Loss 0.123 | T_Acc 0.957 | V_Loss 0.645 | V_Acc 0.831 | 1.009
# Epoch: 279 | T_Loss 0.148 | T_Acc 0.944 | V_Loss 0.678 | V_Acc 0.794 | 1.314
# Epoch: 278 | T_Loss 0.138 | T_Acc  0.95 | V_Loss 0.676 | V_Acc 0.781 | 1.295
# Epoch: 277 | T_Loss 0.092 | T_Acc 0.967 | V_Loss 0.743 | V_Acc 0.819 | 1.038
# Epoch: 276 | T_Loss  0.08 | T_Acc 0.975 | V_Loss 0.667 | V_Acc 0.806 | 0.993
# Epoch: 275 | T_Loss 0.087 | T_Acc 0.966 | V_Loss 0.767 | V_Acc 0.806 | 1.011
# Epoch: 274 | T_Loss 0.134 | T_Acc 0.958 | V_Loss 0.723 | V_Acc 0.788 | 1.004
# Epoch: 273 | T_Loss 0.132 | T_Acc 0.952 | V_Loss 0.767 | V_Acc 0.769 | 0.992
# Epoch: 272 | T_Loss 0.097 | T_Acc  0.97 | V_Loss 0.806 | V_Acc   0.8 | 0.929
# Epoch: 271 | T_Loss  0.08 | T_Acc 0.976 | V_Loss 0.725 | V_Acc 0.806 | 1.337
# Epoch: 270 | T_Loss   0.1 | T_Acc 0.967 | V_Loss 0.745 | V_Acc 0.819 | 1.126
# Epoch: 269 | T_Loss 0.113 | T_Acc 0.963 | V_Loss 0.681 | V_Acc 0.794 | 0.997
# Epoch: 268 | T_Loss 0.167 | T_Acc 0.935 | V_Loss 0.776 | V_Acc 0.769 | 1.003
# Epoch: 267 | T_Loss 0.111 | T_Acc 0.962 | V_Loss 0.753 | V_Acc 0.763 | 0.994
# Epoch: 266 | T_Loss 0.151 | T_Acc 0.941 | V_Loss 0.774 | V_Acc 0.769 | 1.021
# Epoch: 265 | T_Loss 0.085 | T_Acc 0.974 | V_Loss 0.702 | V_Acc 0.806 | 1.011
# Epoch: 264 | T_Loss 0.134 | T_Acc 0.947 | V_Loss 0.724 | V_Acc 0.806 | 1.068
# Epoch: 263 | T_Loss 0.091 | T_Acc 0.967 | V_Loss 0.704 | V_Acc 0.806 | 1.335
# Epoch: 262 | T_Loss 0.091 | T_Acc  0.97 | V_Loss 0.724 | V_Acc 0.788 | 1.044
# Epoch: 261 | T_Loss 0.132 | T_Acc 0.952 | V_Loss 0.636 | V_Acc 0.794 |  0.99
# Epoch: 260 | T_Loss 0.124 | T_Acc 0.949 | V_Loss  0.66 | V_Acc 0.806 | 1.001
# Epoch: 259 | T_Loss  0.14 | T_Acc 0.947 | V_Loss 0.612 | V_Acc 0.794 | 1.048
# Epoch: 258 | T_Loss  0.14 | T_Acc  0.95 | V_Loss 0.725 | V_Acc 0.781 | 0.993
# Epoch: 257 | T_Loss 0.138 | T_Acc 0.948 | V_Loss 0.706 | V_Acc   0.8 | 1.014
# Epoch: 256 | T_Loss 0.136 | T_Acc 0.948 | V_Loss 0.731 | V_Acc 0.788 |   1.2
# Epoch: 255 | T_Loss 0.132 | T_Acc  0.95 | V_Loss 0.601 | V_Acc   0.8 | 1.323
# Epoch: 254 | T_Loss 0.178 | T_Acc 0.925 | V_Loss 0.661 | V_Acc 0.788 |   1.0
# Epoch: 253 | T_Loss 0.113 | T_Acc 0.955 | V_Loss 0.677 | V_Acc 0.806 | 0.996
# Epoch: 252 | T_Loss 0.125 | T_Acc 0.946 | V_Loss 0.667 | V_Acc 0.775 | 0.989
# Epoch: 251 | T_Loss 0.102 | T_Acc 0.963 | V_Loss 0.602 | V_Acc 0.788 | 0.971
# Epoch: 250 | T_Loss 0.109 | T_Acc 0.961 | V_Loss 0.597 | V_Acc 0.825 | 0.996
# Epoch: 249 | T_Loss 0.139 | T_Acc 0.948 | V_Loss 0.544 | V_Acc 0.819 | 0.992
# Epoch: 248 | T_Loss 0.211 | T_Acc  0.91 | V_Loss 0.538 | V_Acc 0.813 | 1.297
# Epoch: 247 | T_Loss 0.271 | T_Acc 0.885 | V_Loss 0.555 | V_Acc 0.788 | 1.306
# Epoch: 246 | T_Loss 0.411 | T_Acc 0.834 | V_Loss 0.587 | V_Acc  0.75 | 0.981
# Epoch: 245 | T_Loss  0.15 | T_Acc 0.939 | V_Loss 0.704 | V_Acc 0.788 |   1.0
# Epoch: 244 | T_Loss 0.141 | T_Acc 0.946 | V_Loss 0.702 | V_Acc 0.794 | 0.984
# Epoch: 243 | T_Loss 0.131 | T_Acc 0.953 | V_Loss 0.711 | V_Acc 0.775 | 0.993
# Epoch: 242 | T_Loss 0.161 | T_Acc 0.934 | V_Loss  0.65 | V_Acc 0.788 |  0.97
# Epoch: 241 | T_Loss 0.169 | T_Acc 0.939 | V_Loss 0.606 | V_Acc 0.838 | 0.987
# Epoch: 240 | T_Loss 0.184 | T_Acc 0.925 | V_Loss 0.632 | V_Acc 0.794 | 1.322
# Epoch: 239 | T_Loss 0.199 | T_Acc 0.917 | V_Loss 0.564 | V_Acc 0.794 | 1.308
# Epoch: 238 | T_Loss 0.181 | T_Acc 0.931 | V_Loss 0.555 | V_Acc 0.825 | 0.989
# Epoch: 237 | T_Loss 0.158 | T_Acc 0.931 | V_Loss 0.618 | V_Acc 0.756 | 0.999
# Epoch: 236 | T_Loss 0.202 | T_Acc 0.918 | V_Loss  0.75 | V_Acc 0.713 | 1.002
# Epoch: 235 | T_Loss 0.175 | T_Acc 0.935 | V_Loss 0.562 | V_Acc 0.806 | 0.993
# Epoch: 234 | T_Loss 0.254 | T_Acc 0.897 | V_Loss 0.605 | V_Acc 0.756 | 0.985
# Epoch: 233 | T_Loss 0.191 | T_Acc 0.925 | V_Loss 0.637 | V_Acc 0.756 | 1.006
# Epoch: 232 | T_Loss 0.192 | T_Acc 0.925 | V_Loss 0.636 | V_Acc 0.781 | 1.338
# Epoch: 231 | T_Loss 0.188 | T_Acc 0.925 | V_Loss 0.557 | V_Acc 0.825 |  1.32
# Epoch: 230 | T_Loss 0.213 | T_Acc 0.916 | V_Loss 0.579 | V_Acc 0.813 | 0.994
# Epoch: 229 | T_Loss 0.255 | T_Acc 0.893 | V_Loss 0.625 | V_Acc 0.788 | 0.996
# Epoch: 228 | T_Loss 0.343 | T_Acc 0.847 | V_Loss 0.597 | V_Acc 0.769 |  0.99
# Epoch: 227 | T_Loss 0.514 | T_Acc 0.761 | V_Loss 0.563 | V_Acc 0.712 | 0.951
# Epoch: 226 | T_Loss 0.225 | T_Acc 0.903 | V_Loss 0.687 | V_Acc 0.788 |  0.99
# Epoch: 225 | T_Loss 0.232 | T_Acc 0.898 | V_Loss 0.625 | V_Acc 0.738 | 0.985
# Epoch: 224 | T_Loss 0.275 | T_Acc 0.894 | V_Loss 0.605 | V_Acc 0.775 | 1.363
# Epoch: 223 | T_Loss 0.251 | T_Acc 0.899 | V_Loss 0.644 | V_Acc 0.781 | 1.314
# Epoch: 222 | T_Loss 0.269 | T_Acc 0.889 | V_Loss 0.578 | V_Acc   0.8 | 0.984
# Epoch: 221 | T_Loss 0.286 | T_Acc 0.889 | V_Loss 0.669 | V_Acc 0.738 | 0.975
# Epoch: 220 | T_Loss 0.238 | T_Acc   0.9 | V_Loss  0.79 | V_Acc 0.738 | 0.932
# Epoch: 219 | T_Loss 0.195 | T_Acc 0.928 | V_Loss 0.682 | V_Acc 0.762 | 0.984
# Epoch: 218 | T_Loss 0.184 | T_Acc 0.929 | V_Loss 0.706 | V_Acc 0.775 | 0.988
# Epoch: 217 | T_Loss 0.176 | T_Acc 0.936 | V_Loss 0.743 | V_Acc 0.763 | 0.976
# Epoch: 216 | T_Loss 0.216 | T_Acc  0.92 | V_Loss 0.676 | V_Acc 0.788 | 1.331
# Epoch: 215 | T_Loss 0.228 | T_Acc 0.911 | V_Loss 0.607 | V_Acc 0.781 | 1.338
# Epoch: 214 | T_Loss  0.23 | T_Acc 0.909 | V_Loss 0.712 | V_Acc 0.769 | 0.983
# Epoch: 213 | T_Loss 0.197 | T_Acc  0.93 | V_Loss 0.677 | V_Acc 0.769 | 0.984
# Epoch: 212 | T_Loss 0.202 | T_Acc  0.93 | V_Loss 0.583 | V_Acc 0.806 | 0.999
# Epoch: 211 | T_Loss 0.275 | T_Acc 0.893 | V_Loss 0.552 | V_Acc   0.8 | 0.977
# Epoch: 210 | T_Loss 0.233 | T_Acc 0.911 | V_Loss 0.609 | V_Acc 0.775 | 0.987
# Epoch: 209 | T_Loss 0.275 | T_Acc 0.889 | V_Loss 0.564 | V_Acc 0.806 | 0.993
# Epoch: 208 | T_Loss 0.245 | T_Acc   0.9 | V_Loss 0.715 | V_Acc 0.756 | 1.339
# Epoch: 207 | T_Loss 0.219 | T_Acc 0.917 | V_Loss 0.657 | V_Acc 0.756 | 1.311
# Epoch: 206 | T_Loss 0.239 | T_Acc 0.907 | V_Loss 0.621 | V_Acc 0.794 | 1.003
# Epoch: 205 | T_Loss 0.252 | T_Acc 0.904 | V_Loss 0.629 | V_Acc 0.775 | 0.981
# Epoch: 204 | T_Loss 0.292 | T_Acc  0.88 | V_Loss  0.62 | V_Acc 0.756 | 0.996
# Epoch: 203 | T_Loss 0.338 | T_Acc 0.848 | V_Loss 0.626 | V_Acc 0.775 | 0.988
# Epoch: 202 | T_Loss 0.313 | T_Acc 0.868 | V_Loss  0.58 | V_Acc 0.781 | 0.974
# Epoch: 201 | T_Loss 0.304 | T_Acc 0.872 | V_Loss 0.534 | V_Acc 0.775 | 0.985
# Epoch: 200 | T_Loss 0.311 | T_Acc 0.876 | V_Loss 0.548 | V_Acc 0.794 | 1.344
# Epoch: 199 | T_Loss 0.227 | T_Acc 0.913 | V_Loss 0.574 | V_Acc 0.775 |  1.31
# Epoch: 198 | T_Loss 0.238 | T_Acc 0.903 | V_Loss 0.547 | V_Acc 0.806 | 0.971
# Epoch: 197 | T_Loss 0.283 | T_Acc 0.887 | V_Loss 0.607 | V_Acc 0.794 | 0.978
# Epoch: 196 | T_Loss  0.25 | T_Acc 0.907 | V_Loss 0.541 | V_Acc   0.8 | 0.979
# Epoch: 195 | T_Loss 0.234 | T_Acc 0.909 | V_Loss 0.551 | V_Acc 0.819 | 0.964
# Epoch: 194 | T_Loss 0.239 | T_Acc 0.903 | V_Loss 0.529 | V_Acc 0.806 | 0.967
# Epoch: 193 | T_Loss 0.266 | T_Acc 0.886 | V_Loss 0.498 | V_Acc 0.788 | 0.961
# Epoch: 192 | T_Loss 0.246 | T_Acc 0.902 | V_Loss 0.586 | V_Acc 0.763 | 1.326
# Epoch: 191 | T_Loss 0.255 | T_Acc 0.897 | V_Loss 0.554 | V_Acc 0.775 |  1.28
# Epoch: 190 | T_Loss 0.272 | T_Acc 0.896 | V_Loss 0.539 | V_Acc 0.769 | 0.973
# Epoch: 189 | T_Loss 0.335 | T_Acc 0.857 | V_Loss 0.537 | V_Acc 0.775 | 0.961
# Epoch: 188 | T_Loss 0.488 | T_Acc 0.767 | V_Loss 0.524 | V_Acc 0.775 | 1.028
# Epoch: 187 | T_Loss 0.418 | T_Acc 0.819 | V_Loss 0.597 | V_Acc 0.588 | 0.986
# Epoch: 186 | T_Loss  0.25 | T_Acc 0.898 | V_Loss 0.552 | V_Acc 0.806 | 0.985
# Epoch: 185 | T_Loss 0.279 | T_Acc 0.888 | V_Loss 0.551 | V_Acc 0.775 | 0.962
# Epoch: 184 | T_Loss 0.318 | T_Acc 0.874 | V_Loss 0.516 | V_Acc 0.775 | 1.322
# Epoch: 183 | T_Loss 0.408 | T_Acc 0.819 | V_Loss 0.513 | V_Acc 0.781 | 1.235
# Epoch: 182 | T_Loss 0.346 | T_Acc 0.857 | V_Loss 0.617 | V_Acc 0.788 | 0.967
# Epoch: 181 | T_Loss   0.3 | T_Acc 0.873 | V_Loss 0.603 | V_Acc 0.744 | 0.974
# Epoch: 180 | T_Loss 0.295 | T_Acc 0.878 | V_Loss 0.515 | V_Acc   0.8 | 0.976
# Epoch: 179 | T_Loss 0.286 | T_Acc 0.877 | V_Loss 0.629 | V_Acc 0.781 | 0.972
# Epoch: 178 | T_Loss 0.314 | T_Acc 0.863 | V_Loss 0.605 | V_Acc  0.75 | 0.962
# Epoch: 177 | T_Loss 0.396 | T_Acc  0.83 | V_Loss 0.563 | V_Acc 0.756 |  0.98
# Epoch: 176 | T_Loss 0.328 | T_Acc 0.857 | V_Loss 0.598 | V_Acc 0.775 | 1.301
# Epoch: 175 | T_Loss 0.282 | T_Acc 0.878 | V_Loss 0.628 | V_Acc 0.769 | 1.256
# Epoch: 174 | T_Loss   0.3 | T_Acc 0.875 | V_Loss 0.557 | V_Acc   0.8 | 0.972
# Epoch: 173 | T_Loss 0.264 | T_Acc 0.893 | V_Loss 0.658 | V_Acc 0.763 | 0.986
# Epoch: 172 | T_Loss 0.291 | T_Acc  0.88 | V_Loss  0.58 | V_Acc 0.769 | 0.959
# Epoch: 171 | T_Loss 0.274 | T_Acc 0.885 | V_Loss 0.593 | V_Acc 0.756 | 0.964
# Epoch: 170 | T_Loss 0.303 | T_Acc 0.874 | V_Loss 0.529 | V_Acc 0.788 |   1.0
# Epoch: 169 | T_Loss 0.312 | T_Acc  0.87 | V_Loss 0.609 | V_Acc 0.781 | 0.965
# Epoch: 168 | T_Loss 0.283 | T_Acc 0.882 | V_Loss 0.595 | V_Acc 0.781 | 1.317
# Epoch: 167 | T_Loss 0.303 | T_Acc  0.87 | V_Loss 0.566 | V_Acc 0.775 | 1.221
# Epoch: 166 | T_Loss 0.338 | T_Acc 0.866 | V_Loss 0.551 | V_Acc 0.756 | 0.976
# Epoch: 165 | T_Loss 0.336 | T_Acc 0.862 | V_Loss 0.535 | V_Acc 0.794 | 0.976
# Epoch: 164 | T_Loss 0.327 | T_Acc 0.862 | V_Loss 0.602 | V_Acc 0.775 | 0.965
# Epoch: 163 | T_Loss 0.309 | T_Acc 0.874 | V_Loss 0.539 | V_Acc 0.769 | 0.964
# Epoch: 162 | T_Loss 0.316 | T_Acc 0.866 | V_Loss 0.588 | V_Acc 0.763 | 0.965
# Epoch: 161 | T_Loss 0.301 | T_Acc 0.871 | V_Loss 0.619 | V_Acc  0.75 | 0.966
# Epoch: 160 | T_Loss 0.307 | T_Acc 0.873 | V_Loss 0.634 | V_Acc 0.744 | 1.305
# Epoch: 159 | T_Loss 0.331 | T_Acc 0.857 | V_Loss 0.522 | V_Acc 0.788 | 1.308
# Epoch: 158 | T_Loss 0.323 | T_Acc 0.852 | V_Loss 0.594 | V_Acc 0.781 | 0.965
# Epoch: 157 | T_Loss 0.329 | T_Acc 0.854 | V_Loss 0.517 | V_Acc   0.8 |  0.97
# Epoch: 156 | T_Loss 0.309 | T_Acc 0.867 | V_Loss 0.578 | V_Acc 0.763 | 0.958
# Epoch: 155 | T_Loss 0.353 | T_Acc 0.846 | V_Loss 0.529 | V_Acc 0.781 | 0.952
# Epoch: 154 | T_Loss 0.371 | T_Acc 0.834 | V_Loss 0.542 | V_Acc 0.775 | 0.987
# Epoch: 153 | T_Loss 0.316 | T_Acc 0.861 | V_Loss 0.528 | V_Acc 0.794 | 0.976
# Epoch: 152 | T_Loss 0.306 | T_Acc 0.868 | V_Loss  0.55 | V_Acc 0.781 | 1.359
# Epoch: 151 | T_Loss 0.315 | T_Acc 0.864 | V_Loss 0.514 | V_Acc 0.794 |  1.31
# Epoch: 150 | T_Loss 0.323 | T_Acc 0.854 | V_Loss 0.527 | V_Acc 0.788 | 0.958
# Epoch: 149 | T_Loss 0.353 | T_Acc 0.841 | V_Loss 0.518 | V_Acc 0.769 | 0.954
# Epoch: 148 | T_Loss 0.353 | T_Acc 0.848 | V_Loss 0.489 | V_Acc 0.775 |  0.96
# Epoch: 147 | T_Loss 0.373 | T_Acc 0.837 | V_Loss 0.552 | V_Acc 0.775 | 0.957
# Epoch: 146 | T_Loss 0.365 | T_Acc 0.841 | V_Loss 0.557 | V_Acc 0.731 | 0.957
# Epoch: 145 | T_Loss 0.338 | T_Acc 0.855 | V_Loss 0.561 | V_Acc 0.763 |  0.96
# Epoch: 144 | T_Loss 0.358 | T_Acc 0.842 | V_Loss 0.532 | V_Acc 0.756 | 1.325
# Epoch: 143 | T_Loss 0.357 | T_Acc 0.846 | V_Loss 0.558 | V_Acc  0.75 | 1.283
# Epoch: 142 | T_Loss 0.345 | T_Acc 0.848 | V_Loss 0.538 | V_Acc 0.794 | 0.959
# Epoch: 141 | T_Loss  0.36 | T_Acc 0.839 | V_Loss 0.501 | V_Acc 0.756 | 0.959
# Epoch: 140 | T_Loss 0.351 | T_Acc  0.85 | V_Loss 0.551 | V_Acc 0.769 | 0.939
# Epoch: 139 | T_Loss 0.357 | T_Acc  0.84 | V_Loss  0.54 | V_Acc 0.788 |  0.96
# Epoch: 138 | T_Loss 0.366 | T_Acc 0.845 | V_Loss 0.543 | V_Acc 0.781 | 0.959
# Epoch: 137 | T_Loss 0.417 | T_Acc 0.816 | V_Loss 0.489 | V_Acc 0.769 | 0.949
# Epoch: 136 | T_Loss  0.34 | T_Acc 0.848 | V_Loss 0.531 | V_Acc 0.788 | 1.289
# Epoch: 135 | T_Loss 0.377 | T_Acc 0.832 | V_Loss 0.495 | V_Acc 0.781 | 1.289
# Epoch: 134 | T_Loss 0.393 | T_Acc 0.827 | V_Loss 0.549 | V_Acc 0.763 | 0.982
# Epoch: 133 | T_Loss 0.443 | T_Acc 0.804 | V_Loss  0.51 | V_Acc 0.769 |  0.96
# Epoch: 132 | T_Loss 0.385 | T_Acc 0.835 | V_Loss 0.563 | V_Acc  0.75 | 0.947
# Epoch: 131 | T_Loss 0.355 | T_Acc 0.846 | V_Loss 0.548 | V_Acc 0.769 | 0.957
# Epoch: 130 | T_Loss 0.386 | T_Acc  0.83 | V_Loss 0.549 | V_Acc 0.769 | 0.952
# Epoch: 129 | T_Loss 0.392 | T_Acc 0.816 | V_Loss 0.517 | V_Acc 0.788 | 0.966
# Epoch: 128 | T_Loss 0.412 | T_Acc 0.816 | V_Loss 0.498 | V_Acc 0.794 | 1.275
# Epoch: 127 | T_Loss 0.436 | T_Acc 0.805 | V_Loss 0.521 | V_Acc 0.788 | 1.319
# Epoch: 126 | T_Loss 0.378 | T_Acc 0.848 | V_Loss 0.574 | V_Acc 0.769 | 0.961
# Epoch: 125 | T_Loss 0.374 | T_Acc  0.84 | V_Loss 0.518 | V_Acc 0.781 | 0.956
# Epoch: 124 | T_Loss 0.413 | T_Acc 0.814 | V_Loss 0.487 | V_Acc 0.794 | 0.952
# Epoch: 123 | T_Loss 0.485 | T_Acc 0.775 | V_Loss 0.556 | V_Acc 0.738 | 0.953
# Epoch: 122 | T_Loss 0.386 | T_Acc  0.83 | V_Loss 0.545 | V_Acc 0.775 | 0.946
# Epoch: 121 | T_Loss 0.406 | T_Acc 0.821 | V_Loss 0.523 | V_Acc 0.769 | 0.955
# Epoch: 120 | T_Loss 0.423 | T_Acc 0.808 | V_Loss 0.525 | V_Acc 0.788 | 1.272
# Epoch: 119 | T_Loss 0.442 | T_Acc 0.803 | V_Loss 0.458 | V_Acc 0.763 | 1.288
# Epoch: 118 | T_Loss 0.388 | T_Acc  0.83 | V_Loss 0.554 | V_Acc 0.769 | 0.949
# Epoch: 117 | T_Loss 0.401 | T_Acc 0.816 | V_Loss 0.528 | V_Acc   0.8 | 0.958
# Epoch: 116 | T_Loss 0.379 | T_Acc 0.832 | V_Loss 0.524 | V_Acc 0.813 | 0.971
# Epoch: 115 | T_Loss 0.385 | T_Acc 0.826 | V_Loss 0.482 | V_Acc 0.775 |  0.94
# Epoch: 114 | T_Loss 0.382 | T_Acc  0.82 | V_Loss 0.556 | V_Acc 0.775 | 0.934
# Epoch: 113 | T_Loss 0.379 | T_Acc 0.833 | V_Loss  0.54 | V_Acc 0.794 | 0.956
# Epoch: 112 | T_Loss 0.385 | T_Acc  0.83 | V_Loss 0.508 | V_Acc   0.8 | 1.259
# Epoch: 111 | T_Loss 0.412 | T_Acc 0.807 | V_Loss 0.529 | V_Acc 0.775 | 1.289
# Epoch: 110 | T_Loss 0.418 | T_Acc 0.816 | V_Loss 0.498 | V_Acc 0.788 | 0.954
# Epoch: 109 | T_Loss 0.395 | T_Acc 0.825 | V_Loss 0.535 | V_Acc 0.763 | 1.252
# Epoch: 108 | T_Loss 0.405 | T_Acc 0.814 | V_Loss 0.507 | V_Acc 0.794 | 1.277
# Epoch: 107 | T_Loss 0.413 | T_Acc 0.817 | V_Loss 0.495 | V_Acc 0.813 | 0.945
# Epoch: 106 | T_Loss 0.423 | T_Acc 0.814 | V_Loss 0.483 | V_Acc 0.781 | 0.942
# Epoch: 105 | T_Loss 0.432 | T_Acc 0.797 | V_Loss 0.495 | V_Acc 0.794 | 0.945
# Epoch: 104 | T_Loss 0.469 | T_Acc 0.789 | V_Loss 0.555 | V_Acc  0.75 | 1.275
# Epoch: 103 | T_Loss 0.395 | T_Acc  0.82 | V_Loss 0.516 | V_Acc 0.788 |  1.07
# Epoch: 102 | T_Loss 0.408 | T_Acc 0.804 | V_Loss 0.509 | V_Acc 0.781 | 0.942
# Epoch: 101 | T_Loss 0.411 | T_Acc 0.807 | V_Loss 0.547 | V_Acc 0.788 | 0.949
# Epoch: 100 | T_Loss  0.42 | T_Acc 0.809 | V_Loss 0.536 | V_Acc 0.781 | 0.949
# Epoch:  99 | T_Loss 0.433 | T_Acc 0.802 | V_Loss 0.488 | V_Acc 0.812 | 0.948
# Epoch:  98 | T_Loss 0.469 | T_Acc 0.767 | V_Loss 0.521 | V_Acc  0.75 | 0.945
# Epoch:  97 | T_Loss 0.413 | T_Acc 0.802 | V_Loss 0.557 | V_Acc 0.781 | 0.948
# Epoch:  96 | T_Loss 0.435 | T_Acc 0.794 | V_Loss  0.57 | V_Acc  0.75 | 1.294
# Epoch:  95 | T_Loss 0.458 | T_Acc 0.778 | V_Loss 0.534 | V_Acc 0.738 | 1.141
# Epoch:  94 | T_Loss 0.432 | T_Acc 0.798 | V_Loss 0.515 | V_Acc 0.775 | 0.954
# Epoch:  93 | T_Loss 0.435 | T_Acc 0.795 | V_Loss 0.499 | V_Acc 0.769 | 0.942
# Epoch:  92 | T_Loss 0.448 | T_Acc 0.788 | V_Loss 0.464 | V_Acc 0.775 | 0.946
# Epoch:  91 | T_Loss 0.445 | T_Acc   0.8 | V_Loss 0.522 | V_Acc  0.75 | 0.938
# Epoch:  90 | T_Loss 0.445 | T_Acc 0.796 | V_Loss 0.516 | V_Acc 0.769 | 0.935
# Epoch:  89 | T_Loss 0.439 | T_Acc 0.798 | V_Loss 0.543 | V_Acc 0.738 |  0.93
# Epoch:  88 | T_Loss 0.444 | T_Acc 0.786 | V_Loss 0.503 | V_Acc 0.738 | 1.276
# Epoch:  87 | T_Loss  0.45 | T_Acc 0.788 | V_Loss 0.503 | V_Acc 0.769 | 1.194
# Epoch:  86 | T_Loss 0.454 | T_Acc 0.784 | V_Loss 0.528 | V_Acc 0.756 | 0.939
# Epoch:  85 | T_Loss 0.462 | T_Acc 0.791 | V_Loss 0.553 | V_Acc 0.744 |  0.94
# Epoch:  84 | T_Loss 0.468 | T_Acc 0.787 | V_Loss 0.503 | V_Acc 0.744 | 0.938
# Epoch:  83 | T_Loss  0.46 | T_Acc 0.787 | V_Loss 0.545 | V_Acc 0.738 | 0.932
# Epoch:  82 | T_Loss 0.459 | T_Acc 0.793 | V_Loss 0.526 | V_Acc  0.75 | 0.942
# Epoch:  81 | T_Loss 0.472 | T_Acc 0.783 | V_Loss 0.527 | V_Acc  0.75 | 0.929
# Epoch:  80 | T_Loss 0.464 | T_Acc 0.791 | V_Loss 0.566 | V_Acc 0.731 | 1.326
# Epoch:  79 | T_Loss 0.459 | T_Acc 0.791 | V_Loss 0.502 | V_Acc 0.775 |  1.33
# Epoch:  78 | T_Loss 0.476 | T_Acc 0.774 | V_Loss  0.49 | V_Acc 0.756 | 0.953
# Epoch:  77 | T_Loss  0.48 | T_Acc 0.775 | V_Loss 0.515 | V_Acc  0.75 | 0.955
# Epoch:  76 | T_Loss 0.473 | T_Acc 0.774 | V_Loss 0.545 | V_Acc 0.731 | 0.949
# Epoch:  75 | T_Loss 0.475 | T_Acc 0.773 | V_Loss 0.525 | V_Acc 0.744 | 0.958
# Epoch:  74 | T_Loss  0.49 | T_Acc 0.764 | V_Loss 0.518 | V_Acc 0.756 | 0.962
# Epoch:  73 | T_Loss 0.494 | T_Acc 0.761 | V_Loss 0.561 | V_Acc 0.725 | 0.946
# Epoch:  72 | T_Loss 0.487 | T_Acc  0.77 | V_Loss 0.537 | V_Acc  0.75 | 1.261
# Epoch:  71 | T_Loss 0.485 | T_Acc 0.767 | V_Loss 0.526 | V_Acc 0.756 | 1.254
# Epoch:  70 | T_Loss 0.482 | T_Acc 0.777 | V_Loss 0.515 | V_Acc 0.763 | 0.922
# Epoch:  69 | T_Loss 0.483 | T_Acc 0.773 | V_Loss 0.511 | V_Acc 0.775 | 0.929
# Epoch:  68 | T_Loss 0.483 | T_Acc 0.764 | V_Loss 0.524 | V_Acc 0.763 | 0.934
# Epoch:  67 | T_Loss 0.496 | T_Acc 0.763 | V_Loss 0.527 | V_Acc 0.756 | 0.932
# Epoch:  66 | T_Loss 0.487 | T_Acc 0.767 | V_Loss 0.533 | V_Acc 0.738 | 0.934
# Epoch:  65 | T_Loss  0.48 | T_Acc  0.78 | V_Loss 0.526 | V_Acc 0.756 | 0.947
# Epoch:  64 | T_Loss 0.477 | T_Acc 0.777 | V_Loss 0.506 | V_Acc 0.744 | 1.054
# Epoch:  63 | T_Loss 0.496 | T_Acc  0.75 | V_Loss 0.515 | V_Acc 0.738 | 1.249
# Epoch:  62 | T_Loss  0.49 | T_Acc 0.755 | V_Loss 0.532 | V_Acc 0.738 | 0.964
# Epoch:  61 | T_Loss 0.495 | T_Acc 0.762 | V_Loss  0.52 | V_Acc 0.731 | 0.935
# Epoch:  60 | T_Loss 0.502 | T_Acc 0.756 | V_Loss 0.536 | V_Acc 0.731 | 0.933
# Epoch:  59 | T_Loss 0.502 | T_Acc 0.753 | V_Loss 0.523 | V_Acc 0.744 | 0.928
# Epoch:  58 | T_Loss 0.499 | T_Acc 0.757 | V_Loss 0.523 | V_Acc 0.731 | 0.928
# Epoch:  57 | T_Loss 0.494 | T_Acc 0.763 | V_Loss 0.519 | V_Acc 0.744 | 0.937
# Epoch:  56 | T_Loss 0.491 | T_Acc 0.766 | V_Loss  0.51 | V_Acc  0.75 | 0.923
# Epoch:  55 | T_Loss 0.499 | T_Acc 0.757 | V_Loss 0.531 | V_Acc 0.731 | 1.257
# Epoch:  54 | T_Loss 0.503 | T_Acc 0.752 | V_Loss 0.526 | V_Acc 0.731 | 1.123
# Epoch:  53 | T_Loss 0.514 | T_Acc 0.747 | V_Loss 0.529 | V_Acc 0.725 | 0.924
# Epoch:  52 | T_Loss 0.527 | T_Acc 0.738 | V_Loss 0.521 | V_Acc 0.725 | 0.921
# Epoch:  51 | T_Loss 0.516 | T_Acc 0.746 | V_Loss 0.524 | V_Acc 0.738 | 0.922
# Epoch:  50 | T_Loss 0.517 | T_Acc 0.743 | V_Loss 0.509 | V_Acc 0.738 | 0.927
# Epoch:  49 | T_Loss 0.524 | T_Acc 0.748 | V_Loss 0.513 | V_Acc 0.725 | 0.918
# Epoch:  48 | T_Loss 0.528 | T_Acc 0.736 | V_Loss 0.519 | V_Acc 0.738 |  0.93
# Epoch:  47 | T_Loss 0.515 | T_Acc 0.745 | V_Loss 0.536 | V_Acc 0.706 | 1.294
# Epoch:  46 | T_Loss 0.514 | T_Acc  0.75 | V_Loss  0.53 | V_Acc 0.725 | 1.294
# Epoch:  45 | T_Loss 0.519 | T_Acc 0.746 | V_Loss 0.529 | V_Acc 0.725 | 0.941
# Epoch:  44 | T_Loss 0.518 | T_Acc 0.746 | V_Loss 0.526 | V_Acc 0.719 |  0.94
# Epoch:  43 | T_Loss 0.521 | T_Acc 0.743 | V_Loss 0.526 | V_Acc 0.713 | 0.922
# Epoch:  42 | T_Loss 0.522 | T_Acc  0.74 | V_Loss 0.527 | V_Acc 0.731 | 0.939
# Epoch:  41 | T_Loss 0.524 | T_Acc 0.741 | V_Loss 0.527 | V_Acc 0.738 | 0.932
# Epoch:  40 | T_Loss 0.526 | T_Acc 0.734 | V_Loss 0.526 | V_Acc 0.744 | 0.919
# Epoch:  39 | T_Loss 0.529 | T_Acc 0.733 | V_Loss 0.527 | V_Acc 0.738 | 1.252
# Epoch:  38 | T_Loss 0.531 | T_Acc 0.731 | V_Loss 0.528 | V_Acc 0.738 |  1.24
# Epoch:  37 | T_Loss 0.539 | T_Acc 0.728 | V_Loss 0.535 | V_Acc 0.731 | 0.912
# Epoch:  36 | T_Loss 0.538 | T_Acc 0.726 | V_Loss 0.542 | V_Acc 0.731 | 0.919
# Epoch:  35 | T_Loss 0.543 | T_Acc  0.72 | V_Loss 0.539 | V_Acc 0.725 |  0.92
# Epoch:  34 | T_Loss 0.567 | T_Acc 0.713 | V_Loss 0.546 | V_Acc 0.719 | 0.929
# Epoch:  33 | T_Loss 0.553 | T_Acc 0.726 | V_Loss 0.545 | V_Acc 0.719 | 0.915
# Epoch:  32 | T_Loss 0.558 | T_Acc 0.718 | V_Loss 0.564 | V_Acc 0.694 | 0.919
# Epoch:  31 | T_Loss 0.556 | T_Acc 0.723 | V_Loss 0.551 | V_Acc 0.694 | 1.034
# Epoch:  30 | T_Loss 0.563 | T_Acc 0.715 | V_Loss 0.554 | V_Acc 0.706 | 1.273
# Epoch:  29 | T_Loss 0.566 | T_Acc 0.716 | V_Loss 0.564 | V_Acc 0.656 | 1.114
# Epoch:  28 | T_Loss 0.571 | T_Acc 0.709 | V_Loss 0.565 | V_Acc 0.663 | 1.102
# Epoch:  27 | T_Loss 0.579 | T_Acc 0.704 | V_Loss 0.568 | V_Acc 0.663 | 0.917
# Epoch:  26 | T_Loss 0.581 | T_Acc 0.696 | V_Loss 0.568 | V_Acc 0.675 | 0.914
# Epoch:  25 | T_Loss 0.587 | T_Acc 0.696 | V_Loss 0.579 | V_Acc 0.688 |  0.94
# Epoch:  24 | T_Loss 0.598 | T_Acc 0.681 | V_Loss 0.563 | V_Acc 0.725 | 0.935
# Epoch:  23 | T_Loss   0.6 | T_Acc 0.686 | V_Loss 0.585 | V_Acc   0.7 | 0.988
# Epoch:  22 | T_Loss 0.608 | T_Acc 0.678 | V_Loss 0.589 | V_Acc 0.688 | 1.232
# Epoch:  21 | T_Loss  0.62 | T_Acc 0.674 | V_Loss 0.589 | V_Acc 0.719 | 1.026
# Epoch:  20 | T_Loss 0.642 | T_Acc 0.648 | V_Loss 0.649 | V_Acc 0.619 | 0.916
# Epoch:  19 | T_Loss 0.656 | T_Acc 0.633 | V_Loss 0.648 | V_Acc 0.638 | 0.913
# Epoch:  18 | T_Loss 0.657 | T_Acc 0.627 | V_Loss  0.64 | V_Acc 0.644 | 0.926
# Epoch:  17 | T_Loss 0.659 | T_Acc 0.621 | V_Loss  0.64 | V_Acc 0.644 | 0.932
# Epoch:  16 | T_Loss 0.662 | T_Acc 0.614 | V_Loss 0.642 | V_Acc 0.638 | 0.911
# Epoch:  15 | T_Loss 0.664 | T_Acc 0.619 | V_Loss 0.658 | V_Acc 0.619 | 0.911
# Epoch:  14 | T_Loss 0.669 | T_Acc 0.601 | V_Loss 0.658 | V_Acc 0.619 | 1.248
# Epoch:  13 | T_Loss 0.677 | T_Acc 0.592 | V_Loss 0.665 | V_Acc 0.619 | 1.229
# Epoch:  12 | T_Loss  0.67 | T_Acc 0.598 | V_Loss 0.627 | V_Acc 0.688 | 0.921
# Epoch:  11 | T_Loss 0.678 | T_Acc 0.587 | V_Loss 0.667 | V_Acc 0.606 | 0.911
# Epoch:  10 | T_Loss 0.682 | T_Acc 0.578 | V_Loss 0.664 | V_Acc 0.625 | 0.917
# Epoch:   9 | T_Loss 0.688 | T_Acc 0.553 | V_Loss 0.667 | V_Acc 0.644 | 0.909
# Epoch:   8 | T_Loss 0.689 | T_Acc 0.548 | V_Loss 0.683 | V_Acc 0.575 | 0.915
# Epoch:   7 | T_Loss 0.693 | T_Acc 0.538 | V_Loss 0.692 | V_Acc 0.494 | 0.926
# Epoch:   6 | T_Loss 0.693 | T_Acc 0.492 | V_Loss 0.692 | V_Acc 0.606 | 1.215
# Epoch:   5 | T_Loss 0.693 | T_Acc  0.47 | V_Loss 0.693 | V_Acc 0.531 | 1.258
# Epoch:   4 | T_Loss 0.694 | T_Acc 0.482 | V_Loss 0.693 | V_Acc 0.506 | 0.898
# Epoch:   3 | T_Loss 0.694 | T_Acc 0.477 | V_Loss 0.693 | V_Acc 0.481 |  0.93
# Epoch:   2 | T_Loss 0.694 | T_Acc  0.48 | V_Loss 0.694 | V_Acc 0.481 | 0.913
# Epoch:   1 | T_Loss 0.695 | T_Acc 0.496 | V_Loss 0.695 | V_Acc 0.481 | 1.813
#
#  Training completed!

# %%
with torch.no_grad():
    tloss, tacc = epoch(test_loader, mode = 'test')
    tacc = round(tacc,4)
    tloss = round(tloss,4)
    print('Test Acc : {},\nTest Los : {}'.format(tacc, tloss))
# Out:
# Test Acc : 0.7835,
# Test Los : 1.9947
